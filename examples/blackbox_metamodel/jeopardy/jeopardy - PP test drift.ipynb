# %% [markdown]
# # Performance Predictor (PP) test drift
#
# Test drift
# - Change logs by percentage of similarity to an example. e.g. higher similarity of logs to less similarity.
#
# In this notebook, we will do the following
# - Start with the WebOfScience dataset
#   - Use the 90 classes with the highest class accuracy size
#     - 90 classes deteremined in notebook:
#       - 'WebOfScience - filter accuracy ordered classes to 0.80 acc and 90 classes.ipynb'
#   - Split the dataset into 2.
#     - Randomize the examples from 90 most accurate classes.
#     - First example is the "split-utterance" example
#     - Sort examples based on similarity/dissimilarity to "split-utterance"
#     - Split remaining into 2 buckets, i.e. similarity to "split-utterance" example, 50% closest & 50% furthest
#   - Drift runs
#     - Generate Runs populating train/test & prod based on percentages from 2 buckets.
#     - Run 1
#       - Train/Test 90% from similar 10% dissimilar
#       - Prod 10% from similar & 90% from dissimilar
#     - Run 2 Train/Test 80%/20% and Prod 20%/80%
#     - Run 3 Train/Test 70%/30% and Prod 30%/70%
#     - Then continue changing similar and dissimilar percentages

# %% [markdown]
# #### Load workspace dataset

# %%
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

from examples.blackbox_metamodel.util import NotebookUtils
from examples.blackbox_metamodel.util import DatasetUtils

os.environ["PYTHONWARNINGS"] = 'ignore'

pd.options.display.max_colwidth = 100

# %load_ext autoreload
# %autoreload 2

# Increase the width of the notebook so that it is the width of the browser 
# which allows larger size for the dashboard
display(HTML('<style>.container { width:100% !important; }</style>'))
# Out:
# 2022-08-27 01:01:03.054318: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-27 01:01:03.054349: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# #### Load the dataset

# %%
# %%time
data_dir = '../../../data'
datasets_info = {k:{} for k in DatasetUtils.constants.keys()}
datasets_info = {'webofscience':{}}
datasets_info = {'jeopardy':{}}
for k, v in datasets_info.items():
    x, y = DatasetUtils().load_dataset(data_dir, k)
    print(f'{k} x.shape = {x.shape}')
    print(f'{k} y.shape = {y.shape}')
    v['x'] = x
    v['y'] = y
# Out:
# jeopardy x.shape = (32623,)
# jeopardy y.shape = (32623,)
# CPU times: user 45.9 ms, sys: 3.57 ms, total: 49.5 ms
# Wall time: 52.7 ms

# %% [markdown]
# #### Encode with USE encoder

# %%
# %%time
for k, v in datasets_info.items():
    x_encoded = NotebookUtils().encode(v['x'], 
                                       DatasetUtils().get_encoded_file_name(data_dir, k))
    v['x_encoded'] = x_encoded
    print(f'{k} x_encoded.shape = {x_encoded.shape}')
# Out:
# jeopardy x_encoded.shape = (32623, 384)
# CPU times: user 2.91 s, sys: 122 ms, total: 3.04 s
# Wall time: 3.04 s

# %% [markdown]
# #### Determine subset datasetd for running experiment
# - keep_intents list is generated in a separate notebook.

# %%
# %%time
for k, v in datasets_info.items():
    x_sub, y_sub = NotebookUtils().subset_dataset(DatasetUtils().get_keep_intents(k), v['x_encoded'], v['y'])
    v['x_sub'] = x_sub
    v['y_sub'] = y_sub
    print(f'{k} x_sub.shape                 = {x_sub.shape}')
    print(f'{k} y_sub.shape                 = {y_sub.shape}')
    print(f'{k} len(np.unique(y_sub)).shape = {len(np.unique(y_sub))}')
# Out:
# jeopardy x_sub.shape                 = (19540, 384)
# jeopardy y_sub.shape                 = (19540,)
# jeopardy len(np.unique(y_sub)).shape = 90
# CPU times: user 83.1 ms, sys: 992 µs, total: 84.1 ms
# Wall time: 86.7 ms

# %% [markdown]
# #### Split to similar & dissimilar buckets
# - Randomize the dataset
# - First example is the "split-utterance" example
# - Use cosine similarity to determine closeness to "split-utterance" example
# - Split datset into similar and dissimilar buckets
#   - in halves - 50% closest & 50% furthest to "split-utterance" example
#   - in quarters - 25% closest and 25% furthest to "split-utterance" example

# %%
# %%time
# Split indices into 2 halves
# 1st half is the dis-similar indices
# 2nd half is the similar indices
dis_count_half = int(len(y) / 2)
sim_count_half = len(y) - dis_count_half

# Split indices into quarters
# 1st half is the dis-similar indices
# 4th half is the similar indices
dis_count_quarter = int(len(y) / 4)
sim_count_quarter = dis_count_quarter

for k, v in datasets_info.items():
    x_split_utterance, y_split_utterance, x, y = NotebookUtils().get_split_utterance(v['x_sub'], v['y_sub'])
    v['x_split_utterance'] = x_split_utterance
    v['y_split_utterance'] = y_split_utterance
    print(f'{k} x_split_utterance.shape = {x_split_utterance.shape}')
    print(f'{k} y_split_utterance.shape = {y_split_utterance.shape}')

    # generate the similar and dissimilar X,y values for half and quarter splits
    for suffix, dis_count, sim_count in zip(['_half', '_quarter'],
                                            [dis_count_half, dis_count_quarter],
                                            [sim_count_half, sim_count_quarter],
                                           ):
        x_dissimilar, y_dissimilar, x_similar, y_similar = NotebookUtils().get_buckets(x_split_utterance, x, y, dis_count, sim_count)
        v[f'x_dissimilar{suffix}'] = x_dissimilar
        v[f'y_dissimilar{suffix}'] = y_dissimilar
        v[f'x_similar{suffix}'] = x_similar
        v[f'y_similar{suffix}'] = y_similar
        print(f'{k} {suffix} x_dissimilar.shape = {x_dissimilar.shape}')
        print(f'{k} {suffix} y_dissimilar.shape = {y_dissimilar.shape}')
        print(f'{k} {suffix} x_similar.shape = {x_similar.shape}')
        print(f'{k} {suffix} y_similar.shape = {y_similar.shape}')
# Out:
# jeopardy x_split_utterance.shape = (1, 384)
# jeopardy y_split_utterance.shape = (1,)
# jeopardy _half x_dissimilar.shape = (16311, 384)
# jeopardy _half y_dissimilar.shape = (16311,)
# jeopardy _half x_similar.shape = (16312, 384)
# jeopardy _half y_similar.shape = (16312,)
# jeopardy _quarter x_dissimilar.shape = (8155, 384)
# jeopardy _quarter y_dissimilar.shape = (8155,)
# jeopardy _quarter x_similar.shape = (8155, 384)
# jeopardy _quarter y_similar.shape = (8155,)
# CPU times: user 356 ms, sys: 287 ms, total: 643 ms
# Wall time: 183 ms

# %% [markdown]
# #### Test drift
# - Drift runs
#   - Generate Runs populating train/test & prod based on percentages from 2 buckets.
#   - Run 1
#     - Train/Test 90% from similar 10% dissimilar
#     - Prod 10% from similar & 90% from dissimilar
#   - Run 2 Train/Test 80%/20% and Prod 20%/80%
#   - Run 3 Train/Test 70%/30% and Prod 30%/70%
#   - Then continue changing similar and dissimilar percentages

# %%
# %%time
train_size = 4609
test_size = 1000
# train_size = round(4609/2)
# test_size = round(1000/2)
split_suffix = '_half'
split_suffix = '_quarter'

percent_sim_runs = [0.98, 0.96, 0.95, 0.94, 0.92, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0.08, 0.06, 0.05, 0.04, 0.02]
# percent_sim_runs = [0.95, 0.9, 0.8, 0.5]
# percent_sim_runs = [0.95, 0.9]
# percent_sim_runs = [0.95]

for k, v in datasets_info.items():
    experiments = NotebookUtils().run_experiments(percent_sim_runs,
                                                  train_size,
                                                  test_size,
                                                  v['x_split_utterance'],
                                                  v['y_split_utterance'],
                                                  v[f'x_similar{split_suffix}'],
                                                  v[f'y_similar{split_suffix}'],
                                                  v[f'x_dissimilar{split_suffix}'],
                                                  v[f'y_dissimilar{split_suffix}'])
    v['experiments'] = experiments
# Out:
# 0 dur=38.64 - svc_train
# 0 dur=17.45 - svc_train_pred
# 0 dur=3.68 - svc_test_pred
# 0 dur=0.00 - svc_split_pred
# 0 dur=33.61 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 0 dur=681.25 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 0 dur=26.97 - pp_train_accuracy  = 61.14%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 0 dur=6.35 - pp_test_accuracy  = 46.74%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 0 dur=0.05 - pp_split_accuracy  = 51.38%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 0 dur=49.77 - pp_prod_accuracy  = 41.31%
# 1 dur=41.76 - svc_train
# 1 dur=17.67 - svc_train_pred
# 1 dur=3.14 - svc_test_pred
# 1 dur=0.00 - svc_split_pred
# 1 dur=30.40 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 1 dur=630.88 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 1 dur=31.29 - pp_train_accuracy  = 56.53%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 1 dur=6.46 - pp_test_accuracy  = 49.13%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 1 dur=0.03 - pp_split_accuracy  = 50.57%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 1 dur=63.25 - pp_prod_accuracy  = 46.59%
# 2 dur=55.15 - svc_train
# 2 dur=16.32 - svc_train_pred
# 2 dur=2.88 - svc_test_pred
# 2 dur=0.00 - svc_split_pred
# 2 dur=29.44 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 2 dur=573.85 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 2 dur=43.25 - pp_train_accuracy  = 51.05%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 2 dur=8.00 - pp_test_accuracy  = 45.28%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 2 dur=0.10 - pp_split_accuracy  = 50.53%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 2 dur=77.12 - pp_prod_accuracy  = 43.36%
# 3 dur=65.76 - svc_train
# 3 dur=20.75 - svc_train_pred
# 3 dur=3.72 - svc_test_pred
# 3 dur=0.00 - svc_split_pred
# 3 dur=27.09 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 3 dur=531.33 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 3 dur=44.34 - pp_train_accuracy  = 55.28%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 3 dur=8.99 - pp_test_accuracy  = 45.04%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 3 dur=0.09 - pp_split_accuracy  = 45.24%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 3 dur=81.98 - pp_prod_accuracy  = 42.58%
# 4 dur=60.49 - svc_train
# 4 dur=16.59 - svc_train_pred
# 4 dur=4.23 - svc_test_pred
# 4 dur=0.00 - svc_split_pred
# 4 dur=34.05 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 4 dur=549.17 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 4 dur=51.47 - pp_train_accuracy  = 60.01%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 4 dur=11.25 - pp_test_accuracy  = 48.94%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 4 dur=0.09 - pp_split_accuracy  = 55.47%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 4 dur=71.95 - pp_prod_accuracy  = 45.00%
# 5 dur=61.81 - svc_train
# 5 dur=17.89 - svc_train_pred
# 5 dur=4.53 - svc_test_pred
# 5 dur=0.00 - svc_split_pred
# 5 dur=39.91 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 5 dur=577.08 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 5 dur=29.18 - pp_train_accuracy  = 57.69%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 5 dur=6.28 - pp_test_accuracy  = 47.18%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 5 dur=0.03 - pp_split_accuracy  = 54.82%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 5 dur=61.57 - pp_prod_accuracy  = 45.67%
# 6 dur=60.33 - svc_train
# 6 dur=22.53 - svc_train_pred
# 6 dur=4.47 - svc_test_pred
# 6 dur=0.00 - svc_split_pred
# 6 dur=44.41 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 6 dur=572.30 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 6 dur=31.80 - pp_train_accuracy  = 55.01%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 6 dur=5.60 - pp_test_accuracy  = 49.28%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 6 dur=0.05 - pp_split_accuracy  = 50.62%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 6 dur=54.79 - pp_prod_accuracy  = 47.72%
# 7 dur=47.30 - svc_train
# 7 dur=13.06 - svc_train_pred
# 7 dur=2.91 - svc_test_pred
# 7 dur=0.00 - svc_split_pred
# 7 dur=30.55 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 7 dur=649.36 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 7 dur=31.27 - pp_train_accuracy  = 53.65%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 7 dur=5.67 - pp_test_accuracy  = 44.86%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 7 dur=0.07 - pp_split_accuracy  = 45.17%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 7 dur=63.13 - pp_prod_accuracy  = 45.12%
# 8 dur=43.47 - svc_train
# 8 dur=16.10 - svc_train_pred
# 8 dur=3.70 - svc_test_pred
# 8 dur=0.00 - svc_split_pred
# 8 dur=36.65 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 8 dur=565.13 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 8 dur=37.33 - pp_train_accuracy  = 60.78%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 8 dur=8.58 - pp_test_accuracy  = 47.57%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 8 dur=0.07 - pp_split_accuracy  = 32.81%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 8 dur=69.22 - pp_prod_accuracy  = 48.41%
# 9 dur=48.58 - svc_train
# 9 dur=13.78 - svc_train_pred
# 9 dur=3.06 - svc_test_pred
# 9 dur=0.00 - svc_split_pred
# 9 dur=31.53 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 9 dur=559.01 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 9 dur=36.34 - pp_train_accuracy  = 57.75%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 9 dur=8.50 - pp_test_accuracy  = 48.93%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 9 dur=0.08 - pp_split_accuracy  = 40.29%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 9 dur=83.42 - pp_prod_accuracy  = 49.10%
# 10 dur=43.68 - svc_train
# 10 dur=16.36 - svc_train_pred
# 10 dur=2.79 - svc_test_pred
# 10 dur=0.00 - svc_split_pred
# 10 dur=33.49 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 10 dur=560.36 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 10 dur=36.08 - pp_train_accuracy  = 61.52%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 10 dur=7.28 - pp_test_accuracy  = 56.10%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 10 dur=0.10 - pp_split_accuracy  = 49.35%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 10 dur=66.03 - pp_prod_accuracy  = 49.43%
# 11 dur=49.08 - svc_train
# 11 dur=18.99 - svc_train_pred
# 11 dur=4.20 - svc_test_pred
# 11 dur=0.00 - svc_split_pred
# 11 dur=45.22 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 11 dur=550.98 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 11 dur=29.32 - pp_train_accuracy  = 55.71%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 11 dur=6.02 - pp_test_accuracy  = 48.03%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 11 dur=0.01 - pp_split_accuracy  = 45.96%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 11 dur=73.00 - pp_prod_accuracy  = 49.38%
# 12 dur=54.42 - svc_train
# 12 dur=25.51 - svc_train_pred
# 12 dur=7.65 - svc_test_pred
# 12 dur=0.00 - svc_split_pred
# 12 dur=44.44 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 12 dur=617.18 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 12 dur=31.67 - pp_train_accuracy  = 57.16%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 12 dur=7.80 - pp_test_accuracy  = 50.47%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 12 dur=0.03 - pp_split_accuracy  = 54.16%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 12 dur=63.50 - pp_prod_accuracy  = 48.91%
# 13 dur=52.14 - svc_train
# 13 dur=22.27 - svc_train_pred
# 13 dur=6.40 - svc_test_pred
# 13 dur=0.00 - svc_split_pred
# 13 dur=29.40 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 13 dur=602.09 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 13 dur=35.05 - pp_train_accuracy  = 59.66%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 13 dur=7.13 - pp_test_accuracy  = 54.01%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 13 dur=0.05 - pp_split_accuracy  = 44.24%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 13 dur=62.52 - pp_prod_accuracy  = 50.39%
# 14 dur=43.85 - svc_train
# 14 dur=14.29 - svc_train_pred
# 14 dur=2.89 - svc_test_pred
# 14 dur=0.00 - svc_split_pred
# 14 dur=28.26 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 14 dur=611.05 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 14 dur=35.49 - pp_train_accuracy  = 60.41%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 14 dur=6.26 - pp_test_accuracy  = 53.33%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 14 dur=0.04 - pp_split_accuracy  = 35.68%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 14 dur=59.35 - pp_prod_accuracy  = 45.02%
# 15 dur=43.23 - svc_train
# 15 dur=15.20 - svc_train_pred
# 15 dur=2.91 - svc_test_pred
# 15 dur=0.00 - svc_split_pred
# 15 dur=26.71 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 15 dur=647.90 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 15 dur=39.49 - pp_train_accuracy  = 60.71%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 15 dur=7.63 - pp_test_accuracy  = 51.40%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 15 dur=0.03 - pp_split_accuracy  = 36.09%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 15 dur=67.38 - pp_prod_accuracy  = 44.67%
# 16 dur=46.49 - svc_train
# 16 dur=19.66 - svc_train_pred
# 16 dur=2.97 - svc_test_pred
# 16 dur=0.00 - svc_split_pred
# 16 dur=27.68 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 16 dur=546.21 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 16 dur=41.34 - pp_train_accuracy  = 57.70%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 16 dur=10.63 - pp_test_accuracy  = 50.40%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 16 dur=0.07 - pp_split_accuracy  = 36.70%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 16 dur=67.48 - pp_prod_accuracy  = 50.52%
# 17 dur=56.30 - svc_train
# 17 dur=15.22 - svc_train_pred
# 17 dur=3.71 - svc_test_pred
# 17 dur=0.00 - svc_split_pred
# 17 dur=28.41 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 17 dur=408.91 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 17 dur=30.41 - pp_train_accuracy  = 59.40%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 17 dur=5.48 - pp_test_accuracy  = 49.78%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 17 dur=0.03 - pp_split_accuracy  = 36.33%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 17 dur=48.72 - pp_prod_accuracy  = 45.43%
# 18 dur=39.50 - svc_train
# 18 dur=12.52 - svc_train_pred
# 18 dur=2.86 - svc_test_pred
# 18 dur=0.00 - svc_split_pred
# 18 dur=24.51 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 18 dur=388.16 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 18 dur=32.45 - pp_train_accuracy  = 60.67%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 18 dur=6.69 - pp_test_accuracy  = 54.81%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 18 dur=0.01 - pp_split_accuracy  = 49.72%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 18 dur=53.38 - pp_prod_accuracy  = 50.46%
# CPU times: user 1h 32min 9s, sys: 20min 40s, total: 1h 52min 49s
# Wall time: 4h 7min 41s

# %% [markdown]
# #### Summarize results

# %%
for k, v in datasets_info.items():
    display(HTML(f'<h2>{k}</h2>'))
    plt.figure()
    data = []
    for e in v['experiments']:
        y_true = [1 if y==p else 0 for y,p in zip(e['y_prod'], e['svc_prod_pred'])]
        fpr, tpr, thresholds = roc_curve(y_true, e['pp_prod_score'], pos_label=1)
        auc = roc_auc_score(y_true, e['pp_prod_score'])
        plt.plot(fpr, tpr, label=f'{auc:.2%} - [{e["sim%"]:.0%}-{e["dis%"]:.0%}]')
        acc_train, _, _, _, _ = NotebookUtils().check_correctness(e['y_train'],  e['svc_train_pred'],  e['pp_train_score'])
        acc_test, _, _, _, _ = NotebookUtils().check_correctness(e['y_test'],  e['svc_test_pred'],  e['pp_test_score'])
        acc_split, _, _, _, _ = NotebookUtils().check_correctness(e['y_split'],  e['svc_split_pred'],  e['pp_split_score'])
        acc, th, tl, fh, fl = NotebookUtils().check_correctness(e['y_prod'],  e['svc_prod_pred'],  e['pp_prod_score'])
        data.append({'dataset': k,
                     'run': e['run'],
                     'sim %': e['sim%'],
                     'dis %': e['dis%'],

                     'train size': len(e['y_train']),
                     'n uniq y_train': len(np.unique(e['y_train'])),
                     'n y_train sim': e['n_y_train_sim'],
                     'n y_train dis': e['n_y_train_dis'],
                     'y_train sim %': e['n_y_train_sim'] / len(e['y_train']),
                     'y_train dis %': e['n_y_train_dis'] / len(e['y_train']),
                     'svc train accuracy': acc_train,
                     'pp train accuracy': e['pp_train_accuracy'],

                     'test size': len(e['y_test']),
                     'n uniq y_test': len(np.unique(e['y_test'])),
                     'n y_test sim': e['n_y_test_sim'],
                     'n y_test dis': e['n_y_test_dis'],
                     'y_test sim %': e['n_y_test_sim'] / len(e['y_test']),
                     'y_test dis %': e['n_y_test_dis'] / len(e['y_test']),
                     'svc test accuracy': acc_test,
                     'pp test accuracy': e['pp_test_accuracy'],

                     'svc split accuracy': acc_split,
                     'pp split accuracy': e['pp_split_accuracy'],

                     'prod size': len(e['y_prod']),
                     'n uniq y_prod': len(np.unique(e['y_prod'])),
                     'n y_prod sim': e['n_y_prod_sim'],
                     'n y_prod dis': e['n_y_prod_dis'],
                     'y_prod sim %': e['n_y_prod_sim'] / len(e['y_prod']),
                     'y_prod dis %': e['n_y_prod_dis'] / len(e['y_prod']),
                     'svc prod accuracy': acc,
                     'pp prod accuracy': e['pp_prod_accuracy'],

                     'TH': th,
                     'TL': tl,
                     'FH': fh,
                     'FL': fl,
                     'AUC': auc,
        })

    pct_fmt = '{:,.2%}'.format
    fmt = {col: pct_fmt for col in ['svc train accuracy', 'pp train accuracy', 'svc test accuracy', 'pp test accuracy',
                                    'svc split accuracy', 'pp split accuracy', 'svc prod accuracy', 'pp prod accuracy',
                                    'TH', 'TL', 'FH', 'FL', 'AUC']}
    for col in ['sim %', 'dis %', 'y_train sim %', 'y_train dis %',
                'y_test sim %', 'y_test dis %', 'y_prod sim %', 'y_prod dis %']:
        fmt[col] = '{:,.0%}'.format

    display(HTML(pd.DataFrame(data).to_html(formatters=fmt)))

    plt.title('Receiver Operating Characteristic')
    plt.legend(loc='lower right')
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
# Out:
# <h2>jeopardy</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dataset</th>
#       <th>run</th>
#       <th>sim %</th>
#       <th>dis %</th>
#       <th>train size</th>
#       <th>n uniq y_train</th>
#       <th>n y_train sim</th>
#       <th>n y_train dis</th>
#       <th>y_train sim %</th>
#       <th>y_train dis %</th>
#       <th>svc train accuracy</th>
#       <th>pp train accuracy</th>
#       <th>test size</th>
#       <th>n uniq y_test</th>
#       <th>n y_test sim</th>
#       <th>n y_test dis</th>
#       <th>y_test sim %</th>
#       <th>y_test dis %</th>
#       <th>svc test accuracy</th>
#       <th>pp test accuracy</th>
#       <th>svc split accuracy</th>
#       <th>pp split accuracy</th>
#       <th>prod size</th>
#       <th>n uniq y_prod</th>
#       <th>n y_prod sim</th>
#       <th>n y_prod dis</th>
#       <th>y_prod sim %</th>
#       <th>y_prod dis %</th>
#       <th>svc prod accuracy</th>
#       <th>pp prod accuracy</th>
#       <th>TH</th>
#       <th>TL</th>
#       <th>FH</th>
#       <th>FL</th>
#       <th>AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>jeopardy</td>
#       <td>8</td>
#       <td>60%</td>
#       <td>40%</td>
#       <td>4609</td>
#       <td>90</td>
#       <td>2765</td>
#       <td>1844</td>
#       <td>60%</td>
#       <td>40%</td>
#       <td>93.17%</td>
#       <td>60.78%</td>
#       <td>1001</td>
#       <td>90</td>
#       <td>601</td>
#       <td>400</td>
#       <td>60%</td>
#       <td>40%</td>
#       <td>48.35%</td>
#       <td>47.57%</td>
#       <td>0.00%</td>
#       <td>32.81%</td>
#       <td>9852</td>
#       <td>90</td>
#       <td>3941</td>
#       <td>5911</td>
#       <td>40%</td>
#       <td>60%</td>
#       <td>49.90%</td>
#       <td>48.41%</td>
#       <td>0.20%</td>
#       <td>49.70%</td>
#       <td>0.02%</td>
#       <td>50.08%</td>
#       <td>69.53%</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>jeopardy</td>
#       <td>9</td>
#       <td>50%</td>
#       <td>50%</td>
#       <td>4609</td>
#       <td>90</td>
#       <td>2304</td>
#       <td>2305</td>
#       <td>50%</td>
#       <td>50%</td>
#       <td>93.04%</td>
#       <td>57.75%</td>

# %%
for k, v in datasets_info.items():
    display(HTML(f'<h2>{k}</h2>'))
    print(f'{k}')
    plt.figure()
    data = []
    for e in v['experiments']:
        y_true = [1 if y==p else 0 for y,p in zip(e['y_prod'], e['svc_prod_pred'])]
        fpr, tpr, thresholds = roc_curve(y_true, e['pp_prod_score'], pos_label=1)
        auc = roc_auc_score(y_true, e['pp_prod_score'])
        plt.plot(fpr, tpr, label=f'{auc:.2%} - [{e["sim%"]:.0%}-{e["dis%"]:.0%}]')
        acc_train, _, _, _, _ = NotebookUtils().check_correctness(e['y_train'],  e['svc_train_pred'],  e['pp_train_score'])
        acc_test, _, _, _, _ = NotebookUtils().check_correctness(e['y_test'],  e['svc_test_pred'],  e['pp_test_score'])
        acc_split, _, _, _, _ = NotebookUtils().check_correctness(e['y_split'],  e['svc_split_pred'],  e['pp_split_score'])
        acc, th, tl, fh, fl = NotebookUtils().check_correctness(e['y_prod'],  e['svc_prod_pred'],  e['pp_prod_score'])
        data.append({'dataset': k,
                     'run': e['run'],
                     'sim %': e['sim%'],
                     'dis %': e['dis%'],
                     'svc train accuracy': acc_train,
                     'svc test accuracy': acc_test,
                     'svc prod accuracy': acc,
                     'pp prod accuracy': e['pp_prod_accuracy'],
                     'train size': len(e['y_train']),
                     'test size': len(e['y_test']),
                     'prod size': len(e['y_prod']),
                     'TH': th,
                     'TL': tl,
                     'FH': fh,
                     'FL': fl,
                     'AUC': auc,
        })

    pct_fmt = '{:,.2%}'.format
    fmt = {col: pct_fmt for col in ['svc train accuracy', 'pp train accuracy',
                                    'svc test accuracy', 'pp test accuracy',
                                    'svc split accuracy', 'pp split accuracy',
                                    'svc prod accuracy', 'pp prod accuracy', 'TH', 'TL', 'FH', 'FL', 'AUC']}
    display(HTML(pd.DataFrame(data).to_html(formatters=fmt)))

    plt.title('Receiver Operating Characteristic')
    plt.legend(loc='lower right')
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
# Out:
# <h2>jeopardy</h2>
# jeopardy
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th
td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>jeopardy</td>
#       <td>15</td>
#       <td>0.06</td>
#       <td>0.94</td>
#       <td>91.82%</td>
#       <td>51.05%</td>
#       <td>41.53%</td>
#       <td>44.67%</td>
#       <td>4609</td>
#       <td>1001</td>
#       <td>8316</td>
#       <td>0.00%</td>
#       <td>41.53%</td>
#       <td>0.00%</td>
#       <td>58.47%</td>
#       <td>71.99%</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>jeopardy</td>
#       <td>16</td>
#       <td>0.05</td>
#       <td>0.95</td>
#       <td>91.84%</td>
#       <td>53.70%</td>
#       <td>41.21%</td>
#       <td>50.52%</td>
#       <td>4609</td>
#       <td>1000</td>
#       <td>8289</td>
#       <td>0.00%</td>
#       <td>41.21%</td>
#       <td>0.00%</td>
#       <td>58.79%</td>
#       <td>66.39%</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>jeopardy</td>
#       <td>17</td>
#       <td>0.04</td>
#       <td>0.96</td>
#       <td>91.76%</td>
#       <td>51.15%</td>
#       <td>40.39%</td>
#       <td>45.43%</td>
#       <td>4609</td>
#       <td>1001</td>
#       <td>8260</td>
#       <td>0.00%</td>
#       <td>40.39%</td>
#       <td>0.00%</td>
#       <td>59.61%</td>
#       <td>69.70%</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>jeopardy</td>
#       <td>18</td>
#       <td>0.02</td>
#       <td>0.98</td>
#       <td>91.39%</td>
#       <td>54.75%</td>
#       <td>38.18%</td>
#       <td>50.46%</td>
#       <td>4609</td>
#       <td>1001</td>
#       <td>8206</td>
#       <td>0.00%</td>
#       <td>38.18%</td>
#       <td>0.00%</td>
#       <td>61.82%</td>
#       <td>69.63%</td>
#     </tr>
#   </tbody>
# </table>

# %%
for k, v in datasets_info.items():
    data = []
    for e in v['experiments']:
        data.append({'dataset': k,
                     'run': e['run'],
                     'sim %': e['sim%'],
                     'dis %': e['dis%'],
                     'n train': len(np.unique(e['y_train'])),
                     'n test': len(np.unique(e['y_test'])),
                     'n prod': len(np.unique(e['y_prod'])),
        })
    display(HTML(pd.DataFrame(data).to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dataset</th>
#       <th>run</th>
#       <th>sim %</th>
#       <th>dis %</th>
#       <th>n train</th>
#       <th>n test</th>
#       <th>n prod</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>jeopardy</td>
#       <td>0</td>
#       <td>0.98</td>
#       <td>0.02</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>jeopardy</td>
#       <td>1</td>
#       <td>0.96</td>
#       <td>0.04</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>jeopardy</td>
#       <td>2</td>
#       <td>0.95</td>
#       <td>0.05</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>jeopardy</td>
#       <td>3</td>
#       <td>0.94</td>
#       <td>0.06</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>jeopardy</td>
#       <td>4</td>
#       <td>0.92</td>
#       <td>0.08</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>jeopardy</td>
#       <td>5</td>
#       <td>0.90</td>
#       <td>0.10</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>jeopardy</td>
#       <td>6</td>
#       <td>0.80</td>
#       <td>0.20</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>jeopardy</td>
#       <td>7</td>
#       <td>0.70</td>
#       <td>0.30</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>jeopardy</td>
#       <td>8</td>
#       <td>0.60</td>
#       <td>0.40</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>jeopardy</td>
#       <td>9</td>
#       <td>0.50</td>
#       <td>0.50</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>jeopardy</td>
#       <td>10</td>
#       <td>0.40</td>
#       <td>0.60</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>jeopardy</td>
#       <td>11</td>
#       <td>0.30</td>
#       <td>0.70</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>jeopardy</td>
#       <td>12</td>
#       <td>0.20</td>
#       <td>0.80</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>jeopardy</td>
#       <td>13</td>
#       <td>0.10</td>
#       <td>0.90</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>jeopardy</td>
#       <td>14</td>
#       <td>0.08</td>
#       <td>0.92</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>jeopardy</td>
#       <td>15</td>
#       <td>0.06</td>
#       <td>0.94</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>jeopardy</td>
#       <td>16</td>
#       <td>0.05</td>
#       <td>0.95</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>jeopardy</td>
#       <td>17</td>
#       <td>0.04</td>
#       <td>0.96</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>jeopardy</td>
#       <td>18</td>
#       <td>0.02</td>
#       <td>0.98</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#   </tbody>
# </table>

# %%
for k, v in datasets_info.items():
    results_file = DatasetUtils().get_results_file_name(data_dir, k)
    df = pd.DataFrame(v['experiments'])
    df.to_parquet(results_file)

# %%
results = {}
for k, v in datasets_info.items():
    results_file = DatasetUtils().get_results_file_name(data_dir, k)
    df = pd.read_parquet(results_file)
    experiments = df.to_dict(orient='records')
    results[k] = {'experiments': experiments}

for k, v in results.items():
    data = []
    for e in v['experiments']:
        data.append({'dataset': k,
                     'run': e['run'],
                     'sim %': e['sim%'],
                     'dis %': e['dis%'],
                     'n train': len(np.unique(e['y_train'])),
                     'n test': len(np.unique(e['y_test'])),
                     'n prod': len(np.unique(e['y_prod'])),
        })
    display(HTML(pd.DataFrame(data).to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dataset</th>
#       <th>run</th>
#       <th>sim %</th>
#       <th>dis %</th>
#       <th>n train</th>
#       <th>n test</th>
#       <th>n prod</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>jeopardy</td>
#       <td>0</td>
#       <td>0.98</td>
#       <td>0.02</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>jeopardy</td>
#       <td>1</td>
#       <td>0.96</td>
#       <td>0.04</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>jeopardy</td>
#       <td>2</td>
#       <td>0.95</td>
#       <td>0.05</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>jeopardy</td>
#       <td>3</td>
#       <td>0.94</td>
#       <td>0.06</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>jeopardy</td>
#       <td>4</td>
#       <td>0.92</td>
#       <td>0.08</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>jeopardy</td>
#       <td>5</td>
#       <td>0.90</td>
#       <td>0.10</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>jeopardy</td>
#       <td>6</td>
#       <td>0.80</td>
#       <td>0.20</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>jeopardy</td>
#       <td>7</td>
#       <td>0.70</td>
#       <td>0.30</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>jeopardy</td>
#       <td>8</td>
#       <td>0.60</td>
#       <td>0.40</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>jeopardy</td>
#       <td>9</td>
#       <td>0.50</td>
#       <td>0.50</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>jeopardy</td>
#       <td>10</td>
#       <td>0.40</td>
#       <td>0.60</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>jeopardy</td>
#       <td>11</td>
#       <td>0.30</td>
#       <td>0.70</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>jeopardy</td>
#       <td>12</td>
#       <td>0.20</td>
#       <td>0.80</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>jeopardy</td>
#       <td>13</td>
#       <td>0.10</td>
#       <td>0.90</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>jeopardy</td>
#       <td>14</td>
#       <td>0.08</td>
#       <td>0.92</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>jeopardy</td>
#       <td>15</td>
#       <td>0.06</td>
#       <td>0.94</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>jeopardy</td>
#       <td>16</td>
#       <td>0.05</td>
#       <td>0.95</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>jeopardy</td>
#       <td>17</td>
#       <td>0.04</td>
#       <td>0.96</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>jeopardy</td>
#       <td>18</td>
#       <td>0.02</td>
#       <td>0.98</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#   </tbody>
# </table>
