# %% [markdown]
# # Performance Predictor (PP) test drift
#
# Test drift
# - Change logs by percentage of similarity to an example. e.g. higher similarity of logs to less similarity.
#
# In this notebook, we will do the following
# - Start with the WebOfScience dataset
#   - Use the 90 classes with the highest class accuracy size
#     - 90 classes deteremined in notebook:
#       - 'WebOfScience - filter accuracy ordered classes to 0.80 acc and 90 classes.ipynb'
#   - Split the dataset into 2.
#     - Randomize the examples from 90 most accurate classes.
#     - First example is the "split-utterance" example
#     - Sort examples based on similarity/dissimilarity to "split-utterance"
#     - Split remaining into 2 buckets, i.e. similarity to "split-utterance" example, 50% closest & 50% furthest
#   - Drift runs
#     - Generate Runs populating train/test & prod based on percentages from 2 buckets.
#     - Run 1
#       - Train/Test 90% from similar 10% dissimilar
#       - Prod 10% from similar & 90% from dissimilar
#     - Run 2 Train/Test 80%/20% and Prod 20%/80%
#     - Run 3 Train/Test 70%/30% and Prod 30%/70%
#     - Then continue changing similar and dissimilar percentages

# %% [markdown]
# #### Load workspace dataset

# %%
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

from examples.blackbox_metamodel.util import NotebookUtils
from examples.blackbox_metamodel.util import DatasetUtils

os.environ["PYTHONWARNINGS"] = 'ignore'

pd.options.display.max_colwidth = 100

# %load_ext autoreload
# %autoreload 2

# Increase the width of the notebook so that it is the width of the browser 
# which allows larger size for the dashboard
display(HTML('<style>.container { width:100% !important; }</style>'))
# Out:
# 2022-08-27 01:01:05.923909: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-27 01:01:05.923947: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# #### Load the dataset

# %%
# %%time
data_dir = '../../../data'
datasets_info = {k:{} for k in DatasetUtils.constants.keys()}
datasets_info = {'webofscience':{}}
for k, v in datasets_info.items():
    x, y = DatasetUtils().load_dataset(data_dir, k)
    print(f'{k} x.shape = {x.shape}')
    print(f'{k} y.shape = {y.shape}')
    v['x'] = x
    v['y'] = y
# Out:
# webofscience x.shape = (46985,)
# webofscience y.shape = (46985,)
# CPU times: user 737 ms, sys: 62 ms, total: 799 ms
# Wall time: 873 ms

# %% [markdown]
# #### Encode with USE encoder

# %%
# %%time
for k, v in datasets_info.items():
    x_encoded = NotebookUtils().encode(v['x'], 
                                       DatasetUtils().get_encoded_file_name(data_dir, k))
    v['x_encoded'] = x_encoded
    print(f'{k} x_encoded.shape = {x_encoded.shape}')
# Out:
# webofscience x_encoded.shape = (46985, 384)
# CPU times: user 5.28 s, sys: 185 ms, total: 5.47 s
# Wall time: 5.47 s

# %% [markdown]
# #### Determine subset datasetd for running experiment
# - keep_intents list is generated in a separate notebook.

# %%
# %%time
for k, v in datasets_info.items():
    x_sub, y_sub = NotebookUtils().subset_dataset(DatasetUtils().get_keep_intents(k), v['x_encoded'], v['y'])
    v['x_sub'] = x_sub
    v['y_sub'] = y_sub
    print(f'{k} x_sub.shape                 = {x_sub.shape}')
    print(f'{k} y_sub.shape                 = {y_sub.shape}')
    print(f'{k} len(np.unique(y_sub)).shape = {len(np.unique(y_sub))}')
# Out:
# webofscience x_sub.shape                 = (33620, 384)
# webofscience y_sub.shape                 = (33620,)
# webofscience len(np.unique(y_sub)).shape = 90
# CPU times: user 435 ms, sys: 4.68 ms, total: 439 ms
# Wall time: 439 ms

# %% [markdown]
# #### Split to similar & dissimilar buckets
# - Randomize the dataset
# - First example is the "split-utterance" example
# - Use cosine similarity to determine closeness to "split-utterance" example
# - Split datset into similar and dissimilar buckets
#   - in halves - 50% closest & 50% furthest to "split-utterance" example
#   - in quarters - 25% closest and 25% furthest to "split-utterance" example

# %%
# %%time
# Split indices into 2 halves
# 1st half is the dis-similar indices
# 2nd half is the similar indices
dis_count_half = int(len(y) / 2)
sim_count_half = len(y) - dis_count_half

# Split indices into quarters
# 1st half is the dis-similar indices
# 4th half is the similar indices
dis_count_quarter = int(len(y) / 4)
sim_count_quarter = dis_count_quarter

for k, v in datasets_info.items():
    x_split_utterance, y_split_utterance, x, y = NotebookUtils().get_split_utterance(v['x_sub'], v['y_sub'])
    v['x_split_utterance'] = x_split_utterance
    v['y_split_utterance'] = y_split_utterance
    print(f'{k} x_split_utterance.shape = {x_split_utterance.shape}')
    print(f'{k} y_split_utterance.shape = {y_split_utterance.shape}')

    # generate the similar and dissimilar X,y values for half and quarter splits
    for suffix, dis_count, sim_count in zip(['_half', '_quarter'],
                                            [dis_count_half, dis_count_quarter],
                                            [sim_count_half, sim_count_quarter],
                                           ):
        x_dissimilar, y_dissimilar, x_similar, y_similar = NotebookUtils().get_buckets(x_split_utterance, x, y, dis_count, sim_count)
        v[f'x_dissimilar{suffix}'] = x_dissimilar
        v[f'y_dissimilar{suffix}'] = y_dissimilar
        v[f'x_similar{suffix}'] = x_similar
        v[f'y_similar{suffix}'] = y_similar
        print(f'{k} {suffix} x_dissimilar.shape = {x_dissimilar.shape}')
        print(f'{k} {suffix} y_dissimilar.shape = {y_dissimilar.shape}')
        print(f'{k} {suffix} x_similar.shape = {x_similar.shape}')
        print(f'{k} {suffix} y_similar.shape = {y_similar.shape}')
# Out:
# webofscience x_split_utterance.shape = (1, 384)
# webofscience y_split_utterance.shape = (1,)
# webofscience _half x_dissimilar.shape = (23492, 384)
# webofscience _half y_dissimilar.shape = (23492,)
# webofscience _half x_similar.shape = (23493, 384)
# webofscience _half y_similar.shape = (23493,)
# webofscience _quarter x_dissimilar.shape = (11746, 384)
# webofscience _quarter y_dissimilar.shape = (11746,)
# webofscience _quarter x_similar.shape = (11746, 384)
# webofscience _quarter y_similar.shape = (11746,)
# CPU times: user 638 ms, sys: 447 ms, total: 1.09 s
# Wall time: 438 ms

# %% [markdown]
# #### Test drift
# - Drift runs
#   - Generate Runs populating train/test & prod based on percentages from 2 buckets.
#   - Run 1
#     - Train/Test 90% from similar 10% dissimilar
#     - Prod 10% from similar & 90% from dissimilar
#   - Run 2 Train/Test 80%/20% and Prod 20%/80%
#   - Run 3 Train/Test 70%/30% and Prod 30%/70%
#   - Then continue changing similar and dissimilar percentages

# %%
# %%time
train_size = 4609
test_size = 1000
# train_size = round(4609/2)
# test_size = round(1000/2)
split_suffix = '_half'
split_suffix = '_quarter'

percent_sim_runs = [0.98, 0.96, 0.95, 0.94, 0.92, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0.08, 0.06, 0.05, 0.04, 0.02]
# percent_sim_runs = [0.95, 0.9, 0.8, 0.5]
# percent_sim_runs = [0.95, 0.9]
# percent_sim_runs = [0.95]

for k, v in datasets_info.items():
    experiments = NotebookUtils().run_experiments(percent_sim_runs,
                                                  train_size,
                                                  test_size,
                                                  v['x_split_utterance'],
                                                  v['y_split_utterance'],
                                                  v[f'x_similar{split_suffix}'],
                                                  v[f'y_similar{split_suffix}'],
                                                  v[f'x_dissimilar{split_suffix}'],
                                                  v[f'y_dissimilar{split_suffix}'])
    v['experiments'] = experiments
# Out:
# 0 dur=31.06 - svc_train
# 0 dur=16.46 - svc_train_pred
# 0 dur=3.54 - svc_test_pred
# 0 dur=0.00 - svc_split_pred
# 0 dur=47.83 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 0 dur=711.65 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 0 dur=31.36 - pp_train_accuracy  = 78.12%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 0 dur=7.53 - pp_test_accuracy  = 60.44%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 0 dur=0.03 - pp_split_accuracy  = 29.43%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 0 dur=91.66 - pp_prod_accuracy  = 27.50%
# 1 dur=49.53 - svc_train
# 1 dur=17.93 - svc_train_pred
# 1 dur=4.93 - svc_test_pred
# 1 dur=0.00 - svc_split_pred
# 1 dur=47.70 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 1 dur=674.27 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 1 dur=39.55 - pp_train_accuracy  = 72.46%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 1 dur=7.35 - pp_test_accuracy  = 63.02%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 1 dur=0.04 - pp_split_accuracy  = 55.44%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 1 dur=125.50 - pp_prod_accuracy  = 42.32%
# 2 dur=46.54 - svc_train
# 2 dur=17.10 - svc_train_pred
# 2 dur=5.11 - svc_test_pred
# 2 dur=0.00 - svc_split_pred
# 2 dur=45.84 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 2 dur=645.08 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 2 dur=51.93 - pp_train_accuracy  = 73.61%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 2 dur=11.91 - pp_test_accuracy  = 63.72%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 2 dur=0.09 - pp_split_accuracy  = 59.25%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 2 dur=111.94 - pp_prod_accuracy  = 46.73%
# 3 dur=45.92 - svc_train
# 3 dur=26.72 - svc_train_pred
# 3 dur=5.48 - svc_test_pred
# 3 dur=0.00 - svc_split_pred
# 3 dur=38.87 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 3 dur=655.79 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 3 dur=60.90 - pp_train_accuracy  = 78.26%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 3 dur=13.97 - pp_test_accuracy  = 60.33%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 3 dur=0.03 - pp_split_accuracy  = 37.46%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 3 dur=107.63 - pp_prod_accuracy  = 40.46%
# 4 dur=39.85 - svc_train
# 4 dur=19.69 - svc_train_pred
# 4 dur=5.24 - svc_test_pred
# 4 dur=0.00 - svc_split_pred
# 4 dur=42.01 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 4 dur=671.61 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 4 dur=35.46 - pp_train_accuracy  = 72.66%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 4 dur=10.76 - pp_test_accuracy  = 62.02%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 4 dur=0.04 - pp_split_accuracy  = 50.96%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 4 dur=116.73 - pp_prod_accuracy  = 53.53%
# 5 dur=42.23 - svc_train
# 5 dur=13.12 - svc_train_pred
# 5 dur=2.81 - svc_test_pred
# 5 dur=0.00 - svc_split_pred
# 5 dur=40.96 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 5 dur=665.28 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 5 dur=37.43 - pp_train_accuracy  = 82.25%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 5 dur=8.38 - pp_test_accuracy  = 64.47%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 5 dur=0.03 - pp_split_accuracy  = 43.62%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 5 dur=101.09 - pp_prod_accuracy  = 53.41%
# 6 dur=39.21 - svc_train
# 6 dur=15.49 - svc_train_pred
# 6 dur=3.04 - svc_test_pred
# 6 dur=0.00 - svc_split_pred
# 6 dur=45.12 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 6 dur=700.22 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 6 dur=38.41 - pp_train_accuracy  = 69.42%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 6 dur=7.12 - pp_test_accuracy  = 62.17%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 6 dur=0.01 - pp_split_accuracy  = 57.02%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 6 dur=92.22 - pp_prod_accuracy  = 59.28%
# 7 dur=38.90 - svc_train
# 7 dur=17.16 - svc_train_pred
# 7 dur=3.51 - svc_test_pred
# 7 dur=0.00 - svc_split_pred
# 7 dur=49.08 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 7 dur=627.58 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 7 dur=33.99 - pp_train_accuracy  = 67.50%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 7 dur=7.81 - pp_test_accuracy  = 64.63%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 7 dur=0.06 - pp_split_accuracy  = 48.90%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 7 dur=132.03 - pp_prod_accuracy  = 58.51%
# 8 dur=47.30 - svc_train
# 8 dur=28.53 - svc_train_pred
# 8 dur=4.52 - svc_test_pred
# 8 dur=0.00 - svc_split_pred
# 8 dur=68.99 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 8 dur=602.64 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 8 dur=65.52 - pp_train_accuracy  = 78.64%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 8 dur=10.49 - pp_test_accuracy  = 63.81%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 8 dur=0.08 - pp_split_accuracy  = 49.00%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 8 dur=151.05 - pp_prod_accuracy  = 61.76%
# 9 dur=50.93 - svc_train
# 9 dur=18.88 - svc_train_pred
# 9 dur=4.03 - svc_test_pred
# 9 dur=0.00 - svc_split_pred
# 9 dur=71.26 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 9 dur=594.84 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 9 dur=46.97 - pp_train_accuracy  = 73.11%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 9 dur=12.43 - pp_test_accuracy  = 66.03%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 9 dur=0.08 - pp_split_accuracy  = 63.26%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 9 dur=185.21 - pp_prod_accuracy  = 65.32%
# 10 dur=34.31 - svc_train
# 10 dur=13.63 - svc_train_pred
# 10 dur=3.09 - svc_test_pred
# 10 dur=0.00 - svc_split_pred
# 10 dur=45.04 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 10 dur=622.98 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 10 dur=47.41 - pp_train_accuracy  = 69.66%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 10 dur=8.62 - pp_test_accuracy  = 60.87%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 10 dur=0.02 - pp_split_accuracy  = 50.69%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 10 dur=133.01 - pp_prod_accuracy  = 61.53%
# 11 dur=38.23 - svc_train
# 11 dur=17.32 - svc_train_pred
# 11 dur=4.06 - svc_test_pred
# 11 dur=0.00 - svc_split_pred
# 11 dur=52.01 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 11 dur=641.65 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 11 dur=38.89 - pp_train_accuracy  = 86.84%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 11 dur=11.68 - pp_test_accuracy  = 58.34%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 11 dur=0.08 - pp_split_accuracy  = 31.84%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 11 dur=121.89 - pp_prod_accuracy  = 56.62%
# 12 dur=38.41 - svc_train
# 12 dur=16.12 - svc_train_pred
# 12 dur=3.41 - svc_test_pred
# 12 dur=0.00 - svc_split_pred
# 12 dur=44.59 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 12 dur=669.78 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 12 dur=36.37 - pp_train_accuracy  = 65.19%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 12 dur=7.37 - pp_test_accuracy  = 58.56%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 12 dur=0.09 - pp_split_accuracy  = 54.30%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 12 dur=115.27 - pp_prod_accuracy  = 56.87%
# 13 dur=41.71 - svc_train
# 13 dur=18.81 - svc_train_pred
# 13 dur=3.93 - svc_test_pred
# 13 dur=0.00 - svc_split_pred
# 13 dur=46.31 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 13 dur=650.13 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 13 dur=32.26 - pp_train_accuracy  = 70.32%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 13 dur=8.14 - pp_test_accuracy  = 61.93%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 13 dur=0.02 - pp_split_accuracy  = 55.95%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 13 dur=110.58 - pp_prod_accuracy  = 61.71%
# 14 dur=36.60 - svc_train
# 14 dur=14.90 - svc_train_pred
# 14 dur=2.75 - svc_test_pred
# 14 dur=0.00 - svc_split_pred
# 14 dur=39.12 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 14 dur=633.33 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 14 dur=41.60 - pp_train_accuracy  = 64.51%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 14 dur=6.97 - pp_test_accuracy  = 58.82%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 14 dur=0.02 - pp_split_accuracy  = 49.35%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 14 dur=83.66 - pp_prod_accuracy  = 54.02%
# 15 dur=34.29 - svc_train
# 15 dur=11.17 - svc_train_pred
# 15 dur=2.82 - svc_test_pred
# 15 dur=0.00 - svc_split_pred
# 15 dur=35.68 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 15 dur=453.72 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 15 dur=31.26 - pp_train_accuracy  = 68.01%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 15 dur=6.26 - pp_test_accuracy  = 63.01%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 15 dur=0.09 - pp_split_accuracy  = 55.61%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 15 dur=79.73 - pp_prod_accuracy  = 59.76%
# 16 dur=35.95 - svc_train
# 16 dur=10.56 - svc_train_pred
# 16 dur=2.30 - svc_test_pred
# 16 dur=0.00 - svc_split_pred
# 16 dur=31.97 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 16 dur=384.40 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 16 dur=30.67 - pp_train_accuracy  = 66.34%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 16 dur=6.57 - pp_test_accuracy  = 60.23%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 16 dur=0.01 - pp_split_accuracy  = 52.70%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 16 dur=77.57 - pp_prod_accuracy  = 55.80%
# 17 dur=28.98 - svc_train
# 17 dur=12.14 - svc_train_pred
# 17 dur=2.67 - svc_test_pred
# 17 dur=0.00 - svc_split_pred
# 17 dur=31.32 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 17 dur=33265.83 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 17 dur=28.51 - pp_train_accuracy  = 71.32%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 17 dur=6.01 - pp_test_accuracy  = 59.64%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 17 dur=0.01 - pp_split_accuracy  = 38.01%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 17 dur=75.96 - pp_prod_accuracy  = 45.74%
# 18 dur=28.70 - svc_train
# 18 dur=12.63 - svc_train_pred
# 18 dur=2.78 - svc_test_pred
# 18 dur=0.00 - svc_split_pred
# 18 dur=32.63 - svc_prod_predict
# Predictor type : text_ensemble
# calibrator : isotonic_regression
# metamodels considered: {'svm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'gbm': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca'], 'mlp': ['confidence_top', 'confidence_delta', 'confidence_entropy', 'class_frequency', 'mlp', 'svc', 'predicted_class', 'one_class_svm', 'pca']}
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# Balancing data encountered a problem. Using unbalanced data.
# 18 dur=368.91 - pp_fitted
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 18 dur=27.89 - pp_train_accuracy  = 75.31%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 18 dur=6.21 - pp_test_accuracy  = 62.14%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 18 dur=0.01 - pp_split_accuracy  = 39.77%
# Incoming data is already encoded
# Features extracted for : ['class_frequency', 'confidence_delta', 'confidence_entropy', 'confidence_top', 'mlp_1', 'mlp_2', 'one_class_svm', 'pca_1', 'pca_2', 'predicted_class', 'svc_1', 'svc_2']
# 18 dur=72.15 - pp_prod_accuracy  = 50.19%
# CPU times: user 1h 54min 51s, sys: 19min 6s, total: 2h 13min 57s
# Wall time: 13h 40min 44s

# %% [markdown]
# #### Summarize results

# %%
for k, v in datasets_info.items():
    display(HTML(f'<h2>{k}</h2>'))
    plt.figure()
    data = []
    for e in v['experiments']:
        y_true = [1 if y==p else 0 for y,p in zip(e['y_prod'], e['svc_prod_pred'])]
        fpr, tpr, thresholds = roc_curve(y_true, e['pp_prod_score'], pos_label=1)
        auc = roc_auc_score(y_true, e['pp_prod_score'])
        plt.plot(fpr, tpr, label=f'{auc:.2%} - [{e["sim%"]:.0%}-{e["dis%"]:.0%}]')
        acc_train, _, _, _, _ = NotebookUtils().check_correctness(e['y_train'],  e['svc_train_pred'],  e['pp_train_score'])
        acc_test, _, _, _, _ = NotebookUtils().check_correctness(e['y_test'],  e['svc_test_pred'],  e['pp_test_score'])
        acc_split, _, _, _, _ = NotebookUtils().check_correctness(e['y_split'],  e['svc_split_pred'],  e['pp_split_score'])
        acc, th, tl, fh, fl = NotebookUtils().check_correctness(e['y_prod'],  e['svc_prod_pred'],  e['pp_prod_score'])
        data.append({'dataset': k,
                     'run': e['run'],
                     'sim %': e['sim%'],
                     'dis %': e['dis%'],

                     'train size': len(e['y_train']),
                     'n uniq y_train': len(np.unique(e['y_train'])),
                     'n y_train sim': e['n_y_train_sim'],
                     'n y_train dis': e['n_y_train_dis'],
                     'y_train sim %': e['n_y_train_sim'] / len(e['y_train']),
                     'y_train dis %': e['n_y_train_dis'] / len(e['y_train']),
                     'svc train accuracy': acc_train,
                     'pp train accuracy': e['pp_train_accuracy'],

                     'test size': len(e['y_test']),
                     'n uniq y_test': len(np.unique(e['y_test'])),
                     'n y_test sim': e['n_y_test_sim'],
                     'n y_test dis': e['n_y_test_dis'],
                     'y_test sim %': e['n_y_test_sim'] / len(e['y_test']),
                     'y_test dis %': e['n_y_test_dis'] / len(e['y_test']),
                     'svc test accuracy': acc_test,
                     'pp test accuracy': e['pp_test_accuracy'],

                     'svc split accuracy': acc_split,
                     'pp split accuracy': e['pp_split_accuracy'],

                     'prod size': len(e['y_prod']),
                     'n uniq y_prod': len(np.unique(e['y_prod'])),
                     'n y_prod sim': e['n_y_prod_sim'],
                     'n y_prod dis': e['n_y_prod_dis'],
                     'y_prod sim %': e['n_y_prod_sim'] / len(e['y_prod']),
                     'y_prod dis %': e['n_y_prod_dis'] / len(e['y_prod']),
                     'svc prod accuracy': acc,
                     'pp prod accuracy': e['pp_prod_accuracy'],

                     'TH': th,
                     'TL': tl,
                     'FH': fh,
                     'FL': fl,
                     'AUC': auc,
        })

    pct_fmt = '{:,.2%}'.format
    fmt = {col: pct_fmt for col in ['svc train accuracy', 'pp train accuracy', 'svc test accuracy', 'pp test accuracy',
                                    'svc split accuracy', 'pp split accuracy', 'svc prod accuracy', 'pp prod accuracy',
                                    'TH', 'TL', 'FH', 'FL', 'AUC']}
    for col in ['sim %', 'dis %', 'y_train sim %', 'y_train dis %',
                'y_test sim %', 'y_test dis %', 'y_prod sim %', 'y_prod dis %']:
        fmt[col] = '{:,.0%}'.format

    display(HTML(pd.DataFrame(data).to_html(formatters=fmt)))

    plt.title('Receiver Operating Characteristic')
    plt.legend(loc='lower right')
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
# Out:
# <h2>webofscience</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dataset</th>
#       <th>run</th>
#       <th>sim %</th>
#       <th>dis %</th>
#       <th>train size</th>
#       <th>n uniq y_train</th>
#       <th>n y_train sim</th>
#       <th>n y_train dis</th>
#       <th>y_train sim %</th>
#       <th>y_train dis %</th>
#       <th>svc train accuracy</th>
#       <th>pp train accuracy</th>
#       <th>test size</th>
#       <th>n uniq y_test</th>
#       <th>n y_test sim</th>
#       <th>n y_test dis</th>
#       <th>y_test sim %</th>
#       <th>y_test dis %</th>
#       <th>svc test accuracy</th>
#       <th>pp test accuracy</th>
#       <th>svc split accuracy</th>
#       <th>pp split accuracy</th>
#       <th>prod size</th>
#       <th>n uniq y_prod</th>
#       <th>n y_prod sim</th>
#       <th>n y_prod dis</th>
#       <th>y_prod sim %</th>
#       <th>y_prod dis %</th>
#       <th>svc prod accuracy</th>
#       <th>pp prod accuracy</th>
#       <th>TH</th>
#       <th>TL</th>
#       <th>FH</th>
#       <th>FL</th>
#       <th>AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>webofscience</td>
#       <td>8</td>
#       <td>60%</td>
#       <td>40%</td>
#       <td>4609</td>
#       <td>90</td>
#       <td>2765</td>
#       <td>1844</td>
#       <td>60%</td>
#       <td>40%</td>
#       <td>92.12%</td>
#       <td>78.64%</td>
#       <td>1000</td>
#       <td>90</td>
#       <td>600</td>
#       <td>400</td>
#       <td>60%</td>
#       <td>40%</td>
#       <td>63.80%</td>
#       <td>63.81%</td>
#       <td>0.00%</td>
#       <td>49.00%</td>
#       <td>15837</td>
#       <td>90</td>
#       <td>6335</td>
#       <td>9502</td>
#       <td>40%</td>
#       <td>60%</td>
#       <td>61.17%</td>
#       <td>61.76%</td>
#       <td>2.68%</td>
#       <td>58.50%</td>
#       <td>0.14%</td>
#       <td>38.69%</td>
#       <td>75.26%</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>webofscience</td>
#       <td>9</td>
#       <td>50%</td>
#       <td>50%</td>
#       <td>4609</td>
#       <td>90</td>
#       <td>2304</td>
#       <td>2305</td>
#       <td>50%</td>
#       <td>

# %%
for k, v in datasets_info.items():
    display(HTML(f'<h2>{k}</h2>'))
    print(f'{k}')
    plt.figure()
    data = []
    for e in v['experiments']:
        y_true = [1 if y==p else 0 for y,p in zip(e['y_prod'], e['svc_prod_pred'])]
        fpr, tpr, thresholds = roc_curve(y_true, e['pp_prod_score'], pos_label=1)
        auc = roc_auc_score(y_true, e['pp_prod_score'])
        plt.plot(fpr, tpr, label=f'{auc:.2%} - [{e["sim%"]:.0%}-{e["dis%"]:.0%}]')
        acc_train, _, _, _, _ = NotebookUtils().check_correctness(e['y_train'],  e['svc_train_pred'],  e['pp_train_score'])
        acc_test, _, _, _, _ = NotebookUtils().check_correctness(e['y_test'],  e['svc_test_pred'],  e['pp_test_score'])
        acc_split, _, _, _, _ = NotebookUtils().check_correctness(e['y_split'],  e['svc_split_pred'],  e['pp_split_score'])
        acc, th, tl, fh, fl = NotebookUtils().check_correctness(e['y_prod'],  e['svc_prod_pred'],  e['pp_prod_score'])
        data.append({'dataset': k,
                     'run': e['run'],
                     'sim %': e['sim%'],
                     'dis %': e['dis%'],
                     'svc train accuracy': acc_train,
                     'svc test accuracy': acc_test,
                     'svc prod accuracy': acc,
                     'pp prod accuracy': e['pp_prod_accuracy'],
                     'train size': len(e['y_train']),
                     'test size': len(e['y_test']),
                     'prod size': len(e['y_prod']),
                     'TH': th,
                     'TL': tl,
                     'FH': fh,
                     'FL': fl,
                     'AUC': auc,
        })

    pct_fmt = '{:,.2%}'.format
    fmt = {col: pct_fmt for col in ['svc train accuracy', 'pp train accuracy',
                                    'svc test accuracy', 'pp test accuracy',
                                    'svc split accuracy', 'pp split accuracy',
                                    'svc prod accuracy', 'pp prod accuracy', 'TH', 'TL', 'FH', 'FL', 'AUC']}
    display(HTML(pd.DataFrame(data).to_html(formatters=fmt)))

    plt.title('Receiver Operating Characteristic')
    plt.legend(loc='lower right')
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>webofscience</td>
#       <td>12</td>
#       <td>0.20</td>
#       <td>0.80</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>webofscience</td>
#       <td>13</td>
#       <td>0.10</td>
#       <td>0.90</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>webofscience</td>
#       <td>14</td>
#       <td>0.08</td>
#       <td>0.92</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>webofscience</td>
#       <td>15</td>
#       <td>0.06</td>
#       <td>0.94</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>webofscience</td>
#       <td>16</td>
#       <td>0.05</td>
#       <td>0.95</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>webofscience</td>
#       <td>17</td>
#       <td>0.04</td>
#       <td>0.96</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>webofscience</td>
#       <td>18</td>
#       <td>0.02</td>
#       <td>0.98</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#   </tbody>
# </table>

# %%
for k, v in datasets_info.items():
    results_file = DatasetUtils().get_results_file_name(data_dir, k)
    df = pd.DataFrame(v['experiments'])
    df.to_parquet(results_file)

# %%
results = {}
for k, v in datasets_info.items():
    results_file = DatasetUtils().get_results_file_name(data_dir, k)
    df = pd.read_parquet(results_file)
    experiments = df.to_dict(orient='records')
    results[k] = {'experiments': experiments}

for k, v in results.items():
    data = []
    for e in v['experiments']:
        data.append({'dataset': k,
                     'run': e['run'],
                     'sim %': e['sim%'],
                     'dis %': e['dis%'],
                     'n train': len(np.unique(e['y_train'])),
                     'n test': len(np.unique(e['y_test'])),
                     'n prod': len(np.unique(e['y_prod'])),
        })
    display(HTML(pd.DataFrame(data).to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dataset</th>
#       <th>run</th>
#       <th>sim %</th>
#       <th>dis %</th>
#       <th>n train</th>
#       <th>n test</th>
#       <th>n prod</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>webofscience</td>
#       <td>0</td>
#       <td>0.98</td>
#       <td>0.02</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>webofscience</td>
#       <td>1</td>
#       <td>0.96</td>
#       <td>0.04</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>webofscience</td>
#       <td>2</td>
#       <td>0.95</td>
#       <td>0.05</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>webofscience</td>
#       <td>3</td>
#       <td>0.94</td>
#       <td>0.06</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>webofscience</td>
#       <td>4</td>
#       <td>0.92</td>
#       <td>0.08</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>webofscience</td>
#       <td>5</td>
#       <td>0.90</td>
#       <td>0.10</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>webofscience</td>
#       <td>6</td>
#       <td>0.80</td>
#       <td>0.20</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>webofscience</td>
#       <td>7</td>
#       <td>0.70</td>
#       <td>0.30</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>webofscience</td>
#       <td>8</td>
#       <td>0.60</td>
#       <td>0.40</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>webofscience</td>
#       <td>9</td>
#       <td>0.50</td>
#       <td>0.50</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>webofscience</td>
#       <td>10</td>
#       <td>0.40</td>
#       <td>0.60</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>webofscience</td>
#       <td>11</td>
#       <td>0.30</td>
#       <td>0.70</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>webofscience</td>
#       <td>12</td>
#       <td>0.20</td>
#       <td>0.80</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>webofscience</td>
#       <td>13</td>
#       <td>0.10</td>
#       <td>0.90</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>webofscience</td>
#       <td>14</td>
#       <td>0.08</td>
#       <td>0.92</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>webofscience</td>
#       <td>15</td>
#       <td>0.06</td>
#       <td>0.94</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>webofscience</td>
#       <td>16</td>
#       <td>0.05</td>
#       <td>0.95</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>webofscience</td>
#       <td>17</td>
#       <td>0.04</td>
#       <td>0.96</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>webofscience</td>
#       <td>18</td>
#       <td>0.02</td>
#       <td>0.98</td>
#       <td>90</td>
#       <td>90</td>
#       <td>90</td>
#     </tr>
#   </tbody>
# </table>
